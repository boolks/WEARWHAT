# %%
import bs4
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re

# url = 'https://store.musinsa.com/app/items/lists/001'    # 상의
# url = 'https://store.musinsa.com/app/items/lists/003'    # 하의
url = 'https://store.musinsa.com/app/items/lists/022'    # 스커트
# url = 'https://store.musinsa.com/app/items/lists/005'    # 신발
# url = 'https://store.musinsa.com/app/items/lists/020'    # 원피스
htp = 'https://store.musinsa.com/'
res = requests.get(url)
html = res.text
bs = BeautifulSoup(html, 'html.parser')
tag_lists = bs.select('.li_box .li_inner .list_img')
# print(len(tag_lists))
# tag_lists

# %%
# 상세 링크(상의)
cloth_list = []
cloth_lists = []
url2 = 'https:'
for idx, tag in enumerate(tag_lists):
    tag_img = tag.find('a')
    tag_url = tag_img['href']
    link = urljoin(htp,tag_url)
    cloth_list.append(link)

# 상세 페이지 get 요청
for cloth in cloth_list[:90]:          # 일단 5개만!
    cloth_dict = {}

    d_res = requests.get(cloth)
    d_html = d_res.text
    d_bs = BeautifulSoup(d_html, 'html.parser')

    # 옷 이름 파싱
    title = d_bs.select('div.right_contents span.product_title > span')[0].text
    cloth_dict['title'] = title

    # 옷 브랜드 파싱
    brand = d_bs.select('.product_info .item_categories > a')[2].text
    brand = re.sub('[\(\)]', '', brand)
    cloth_dict['brand'] = brand

    # season, gender 태그 파싱
    detail_lists = d_bs.select('ul.product_article li p.product_article_contents')
    detail_list = []
    for idx, detail in enumerate(detail_lists[1]):
        detail_dict = {}
        if isinstance(detail, bs4.element.Tag):
            content = detail.text
            content = content.replace(' ','')
            content = content.replace('\t', '')
            matched = re.search(r'(\D+)', content)
            val = matched.group(1)
            # print(idx, val.strip())
            if idx == 1:
                cloth_dict['season'] = val.strip()
            elif idx == 5:
                cloth_dict['gender'] = val.strip()
            else:
                continue

    # 옷 색깔 파싱
    color = d_bs.select('div.product_info_table > table > tbody > tr > td')[0].text.strip()
    cloth_dict['color'] = color

    # 옷 카테고리 입력ㅋㅋㅋㅋ
    cloth_dict['category'] = '상의'

    # 옷 이미지
    image = d_bs.select(".product_left #detail_bigimg .product-img img")
#     print(image)
    for i in image:
        link = i['src']
#         print(link)
        image_link = urljoin(url2, link)
        cloth_dict['img'] = image_link

    # 옷 링크
    cloth_dict['url'] = cloth

    # 옷 정보 리스트에 추가
    cloth_lists.append(cloth_dict)

print(len(cloth_lists))
cloth_lists
# Out:
# 90
# [{'title': '오버컴 반팔 티셔츠 (3color)',
#   'brand': '이에스엔',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1546358/1546358_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1546358/0'},
#  {'title': 'MGD TEE WHITE(MG2AMMT512A)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190321/990969/990969_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/990969/0'},
#  {'title': 'RAINBOW REFLECTOR PLANET TEE BLACK(MG1JMMT511B)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190327/996166/996166_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/996166/0'},
#  {'title': 'ORIGIN LOGO TEE PINK(MG2AMMT500A)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '분홍색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200323/1363595/1363595_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1363595/0'},
#  {'title': 'MASS TEE BLACK(MG2AMMT512B)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200323/1363601/1363601_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1363601/0'},
#  {'title': 'LOGO LABEL TEE WHITE(MG2AMMT505A)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200325/1367039/1367039_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1367039/0'},
#  {'title': 'RAINBOW REFLECTIVE GROOVY TEE BLACK(MG2AMMT509A)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200325/1367104/1367104_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1367104/0'},
#  {'title': 'THIRD LOGO TEE YELLOW(MG2AMMT508A)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '노란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200325/1367665/1367665_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1367665/0'},
#  {'title': 'RAINBOW REFLECTIVE SHATTER LOGO TEE BLACK(MG2AMMT511A)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200401/1377540/1377540_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1377540/0'},
#  {'title': 'MAKE YOUR GRID TEE BLACK(MG2AMMT500D)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200520/1454385/1454385_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1454385/0'},
#  {'title': 'MAKE YOUR GRID TEE YELLOW(MG2AMMT500D)',
#   'brand': '마하그리드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '노란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200520/1454386/1454386_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1454386/0'},
#  {'title': '19 SUMMER 포스터 티셔츠 (네이비)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190402/1002349/1002349_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1002349/0'},
#  {'title': '19 SUMMER 포스터 티셔츠 (화이트)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190402/1002353/1002353_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1002353/0'},
#  {'title': '19 SUMMER 슬랜트 티셔츠 (오렌지)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '주황색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190404/1004669/1004669_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1004669/0'},
#  {'title': '19 SUMMER 오피셜 로고 티셔츠 (에메랄드 그린)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '녹색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190404/1004942/1004942_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1004942/0'},
#  {'title': '19 SUMMER 척랩 로고 티셔츠 (스카이)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190423/1024613/1024613_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1024613/0'},
#  {'title': '19 SUMMER 시그니처 로고 크롭 티셔츠 (네이비)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190423/1024680/1024680_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1024680/0'},
#  {'title': '19 SUMMER 시그니처 로고 크롭 티셔츠 (화이트)',
#   'brand': '척',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190423/1024681/1024681_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1024681/0'},
#  {'title': '케이덤 헨리 SS 남성 (ATKSM23021)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '올리브 그린',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545772/1545772_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545772/0'},
#  {'title': '아키옵터릭스 티셔츠 SS 남성 (ATKSM24024)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '레드 브라운',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545770/1545770_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545770/0'},
#  {'title': '남성 그레이 외계인  티셔츠',
#   'brand': '굿나잇데이브',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '회색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200811/1545032/1545032_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545032/0'},
#  {'title': '남성 네이비 별똥별 티셔츠',
#   'brand': '굿나잇데이브',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '네이비',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200811/1545037/1545037_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545037/0'},
#  {'title': '남성 화이트 레이저건 티셔츠',
#   'brand': '굿나잇데이브',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200811/1545040/1545040_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545040/0'},
#  {'title': '여성 화이트 레이저건 티셔츠',
#   'brand': '굿나잇데이브',
#   'season': 'S/S',
#   'gender': '여',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200811/1545005/1545005_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545005/0'},
#  {'title': '여성 네이비 별똥별  티셔츠',
#   'brand': '굿나잇데이브',
#   'season': 'S/S',
#   'gender': '여',
#   'color': '네이비',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200811/1545007/1545007_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545007/0'},
#  {'title': '여성 핑크 외계인  티셔츠',
#   'brand': '굿나잇데이브',
#   'season': 'S/S',
#   'gender': '여',
#   'color': '코랄',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200811/1545028/1545028_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545028/0'},
#  {'title': '아크워드 티셔츠 SS 남성 (ATKSM24013)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '네이비',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545769/1545769_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545769/0'},
#  {'title': '코막 로고 셔츠 SS 남성 (ATKSM25154)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '카키',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545768/1545768_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545768/0'},
#  {'title': '볼더 스케이프 티셔츠 남성 (ATKSM25235)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '다크 그린',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545767/1545767_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545767/0'},
#  {'title': '컴포넌트 티셔츠 SS 남성 (ATKSM25233)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '네이비',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545766/1545766_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545766/0'},
#  {'title': '호라이즌 티셔츠 SS 남성 (ATKSM26436)',
#   'brand': '아크테릭스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '민트',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545765/1545765_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545765/0'},
#  {'title': 'SHARK DOG_tshirts-85 샤크독 서프 하와이 여름 서핑 불독 강아지 캐릭터 그래픽 디자인 티셔츠 반팔티',
#   'brand': '돌돌',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1546046/1546046_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1546046/0'},
#  {'title': 'SHARK DOG_tshirts-86 샤크독 서프 하와이 여름 서핑 불독 강아지 캐릭터 그래픽 디자인 티셔츠 반팔티',
#   'brand': '돌돌',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1546045/1546045_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1546045/0'},
#  {'title': 'SHARK DOG_tshirts-87 샤크독 서프 하와이 여름 서핑 불독 강아지 캐릭터 그래픽 디자인 티셔츠 반팔티',
#   'brand': '돌돌',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1546044/1546044_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1546044/0'},
#  {'title': 'SHARK DOG_tshirts-88 샤크독 서프 하와이 여름 서핑 불독 강아지 캐릭터 그래픽 디자인 티셔츠 반팔티',
#   'brand': '돌돌',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1546042/1546042_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1546042/0'},
#  {'title': '마린 디즈니 티셔츠 2003256120141',
#   'brand': '디자인 유나이티드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200702/1504899/1504899_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1504899/0'},
#  {'title': 'DIGITAL CAMO TIGER TEE',
#   'brand': '베이프',
#   'season': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545915/1545915_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545915/0'},
#  {'title': '오버핏 어센틱 티셔츠 2001238120102',
#   'brand': '디자인 유나이티드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200702/1504909/1504909_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1504909/0'},
#  {'title': 'DIGITAL CAMO SIDE APE HEAD RLX TE',
#   'brand': '베이프',
#   'season': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545914/1545914_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545914/0'},
#  {'title': 'DIGITAL CAMO SIDE SHARK TEE',
#   'brand': '베이프',
#   'season': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545913/1545913_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545913/0'},
#  {'title': 'DIGITAL CAMO COLLEGE TEE',
#   'brand': '베이프',
#   'season': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200812/1545912/1545912_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1545912/0'},
#  {'title': '[패키지] NYC LOCATION T-SHIRT (10 COLORS) [GTS721I23]',
#   'brand': '그루브라임',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '기타',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200424/1420730/1420730_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1420730/0'},
#  {'title': '릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]',
#   'brand': '무신사 스탠다드',
#   'season': 'ALL',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190327/996178/996178_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/996178/0'},
#  {'title': '릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]',
#   'brand': '무신사 스탠다드',
#   'season': 'ALL',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190327/996177/996177_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/996177/0'},
#  {'title': 'LMC THREE BEARS TEE white',
#   'brand': '엘엠씨',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200515/1449350/1449350_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1449350/0'},
#  {'title': 'S/S AUTHENTIC LOGO TEE WHITE',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20180330/746280/746280_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/746280/0'},
#  {'title': 'M/G SMALL SIGN LOGO T-SHIRTS BLACK',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20180403/748056/748056_7_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/748056/0'},
#  {'title': 'LMC 5th ANNIV RETRO MOON TEE black',
#   'brand': '엘엠씨',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200414/1404746/1404746_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1404746/0'},
#  {'title': '라인 서퍼맨 티셔츠 화이트',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20180406/751030/751030_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/751030/0'},
#  {'title': 'S/S LAYOUT LOGO TEE BLACK',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190228/968977/968977_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/968977/0'},
#  {'title': '포켓티 블랙 / K87-001',
#   'brand': '칼하트',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20170317/501693/501693_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/501693/0'},
#  {'title': '[패키지]아이스버그 반팔 STST3279 + 스플래쉬 반팔 STST3278',
#   'brand': '티떠블유엔',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '기타',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200428/1425234/1425234_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1425234/0'},
#  {'title': 'LOCATION SHORT SLEEVE JS [BLACK]',
#   'brand': '비바스튜디오',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190425/1027583/1027583_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1027583/0'},
#  {'title': 'M/G SMALL SIGN LOGO T-SHIRTS WHITE',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20180403/748060/748060_8_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/748060/0'},
#  {'title': 'S/S AUTHENTIC LOGO TEE BLACK',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20180330/746276/746276_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/746276/0'},
#  {'title': 'YOUNG 프리미엄 실켓 티셔츠',
#   'brand': '엘무드',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '민트',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200331/1375522/1375522_2_500.png',
#   'url': 'https://store.musinsa.com/app/product/detail/1375522/0'},
#  {'title': 'S/S ARCH LOGO TEE WHITE/RED',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20170414/538899/538899_6_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/538899/0'},
#  {'title': 'M-Logo Classic (GL5TSU173WH)',
#   'brand': '지프',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200318/1356896/1356896_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1356896/0'},
#  {'title': '[패키지] 에디 오버핏 반팔티셔츠 패키지 KJST2189',
#   'brand': '제멋',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '기타',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190319/987149/987149_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/987149/0'},
#  {'title': 'LOCATION SHORT SLEEVE JS [WHITE]',
#   'brand': '비바스튜디오',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190425/1027576/1027576_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1027576/0'},
#  {'title': '[패키지] 9TH ANNIVERSARY 3PACK T-SHIRTS EDITION',
#   'brand': '그루브라임',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '기타',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200408/1390339/1390339_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1390339/0'},
#  {'title': '(2PACK) T425 무지 반팔티',
#   'brand': '챔피온',
#   'color': '기타',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20170315/499561/499561_8_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/499561/0'},
#  {'title': 'M/G ANGEL STRIPE T-SHIRTS BLACK',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200414/1403092/1403092_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1403092/0'},
#  {'title': 'M/G SIGN LOGO T-SHIRTS BLACK',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190404/1005683/1005683_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1005683/0'},
#  {'title': '[패키지][CHUBBY]EMBROIDERY TEE (5COLOR)',
#   'brand': '파르티멘토',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '기타',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200520/1454812/1454812_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1454812/0'},
#  {'title': '서핀 백 프린트 티 셔츠_네이비',
#   'brand': '유니스디자인',
#   'season': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190521/1051406/1051406_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1051406/0'},
#  {'title': '라인 서퍼맨 티셔츠 네이비',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20180406/751029/751029_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/751029/0'},
#  {'title': '[세트상품] 더블 코튼 롱 티셔츠',
#   'brand': '어커버',
#   'season': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20160322/324416/324416_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/324416/0'},
#  {'title': 'N202UTS910 스토크 오버핏 반팔 티셔츠 BLACK 2',
#   'brand': '내셔널지오그래픽',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190329/999287/999287_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/999287/0'},
#  {'title': 'M/G SURFING ANGEL T-SHIRTS WHITE',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200316/1353329/1353329_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1353329/0'},
#  {'title': '베이식 크루 넥 반팔 티셔츠 [화이트]',
#   'brand': '무신사 스탠다드',
#   'season': 'ALL',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190327/996497/996497_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/996497/0'},
#  {'title': 'M/G SIGN LOGO T-SHIRTS WHITE',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190404/1005680/1005680_4_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1005680/0'},
#  {'title': 'LOCATION SHORT SLEEVE JS [INDIGO BLUE]',
#   'brand': '비바스튜디오',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '네온 블루',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190425/1027582/1027582_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1027582/0'},
#  {'title': '베이식 크루 넥 반팔 티셔츠 [블랙]',
#   'brand': '무신사 스탠다드',
#   'season': 'ALL',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190327/996498/996498_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/996498/0'},
#  {'title': '챔피온 T425 무지 반팔티',
#   'brand': '챔피온',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20140422/86965/86965_5_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/86965/0'},
#  {'title': '헤리티지 세리프 로고 루즈핏 반팔티 (FE2RSC5303XGBL)',
#   'brand': '휠라',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '파란색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200109/1266397/1266397_5_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1266397/0'},
#  {'title': 'DSN-Logo Tee White',
#   'brand': '디스이즈네버댓',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200219/1311681/1311681_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1311681/0'},
#  {'title': 'S/S LAYOUT LOGO TEE RED',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190228/968976/968976_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/968976/0'},
#  {'title': 'M/G SURFING ANGEL T-SHIRTS BLACK',
#   'brand': '마크 곤잘레스',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200316/1353328/1353328_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1353328/0'},
#  {'title': 'Cracked T-Logo Tee White',
#   'brand': '디스이즈네버댓',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200304/1335306/1335306_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1335306/0'},
#  {'title': 'S/S WHALE GRAPHIC TEE BLACK',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190328/997902/997902_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/997902/0'},
#  {'title': '헤리티지 세리프 로고 루즈핏 반팔티 (FE2RSC5303XOWH)',
#   'brand': '휠라',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190329/999577/999577_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/999577/0'},
#  {'title': 'RL001 오리지널 로고 반팔티 화이트',
#   'brand': '로얄라이프',
#   'season': '남\n여',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20170418/540421/540421_7_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/540421/0'},
#  {'title': 'T-Logo Tee Black (002)',
#   'brand': '디스이즈네버댓',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190228/969663/969663_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/969663/0'},
#  {'title': '유니섹스 오버핏 어스넷 로고 티-블랙',
#   'brand': '필루미네이트',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190513/1042880/1042880_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1042880/0'},
#  {'title': 'M-Logo Classic (GL5TSU173IV)',
#   'brand': '지프',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '아이보리',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200402/1383418/1383418_3_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1383418/0'},
#  {'title': 'Kitten Boxy Tee [BLACK]',
#   'brand': '스컬프터',
#   'season': 'S/S',
#   'gender': '여',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200518/1450200/1450200_1_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1450200/0'},
#  {'title': '컬러 그라데이션 오버핏 반팔티셔츠 BLACK',
#   'brand': '트릴리온',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '검정색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190328/997738/997738_5_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/997738/0'},
#  {'title': 'LMC SEAWORLD TEE white',
#   'brand': '엘엠씨',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20200401/1378036/1378036_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/1378036/0'},
#  {'title': 'S/S LAYOUT LOGO TEE WHITE',
#   'brand': '커버낫',
#   'season': 'S/S',
#   'gender': '남',
#   'color': '흰색',
#   'category': '상의',
#   'image': '//image.msscdn.net/images/goods_img/20190228/968975/968975_2_500.jpg',
#   'url': 'https://store.musinsa.com/app/product/detail/968975/0'}]

# %%
# DataFrame 저장
import pandas as pd
import numpy as np
data_df = pd.DataFrame(columns=['title', 'brand', 'season', 'gender', 'color', 'category', 'img', 'url'])
for data in cloth_lists:
    series_obj = pd.Series(data)
    data_df = data_df.append(series_obj, ignore_index=True)

data_df.index = np.arange(1, len(data_df)+1)

data_df.head()
# Out:
#   File "<ipython-input-85-46e2c1a481fe>", line 3
#     result = re.sub('', brand)
#          ^
# SyntaxError: invalid syntax

# %%
# DB 저장 (mariaDB)
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqldb://python:"+"python"+"@localhost/cloth_db", encoding='utf-8')
con = engine.connect()
data_df.to_sql(name='cloth', con=engine, if_exists='replace', index=True, index_label='id')
